# %%
import pandas as pd

# %%
import sys
import os

# Add project root (two levels up from notebooks/eda)
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_root)

from src.api.Nasa_Precipitation import get_precipitation

# %%
precipation_df , coordinates = get_precipitation( 19810101 , 20251230 ,20.593684 ,79 )

# saving raw data

precipation_df.to_csv('../../data/raw/precipation_raw.csv' )
precipation_df.head()
# Out:
#        date  precipitation
# 0  19810101           1.67
# 1  19810102           0.55
# 2  19810103           0.92
# 3  19810104           0.44
# 4  19810105           0.35
