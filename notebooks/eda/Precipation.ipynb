# %%
import pandas as pd

# %%
import sys
import os

# Add project root (two levels up from notebooks/eda)
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_root)

from src.api.world_bank_Precipitation import get_precipitation

# %%
precipation_df = get_precipitation( )
# Out:
# Processing request..
# Fetching page 1/1...
# Done. Collected 17490 records.
# Converting into dataFrame

# %%
# saving raw data

precipation_df.to_csv('../../data/raw/precipation_raw.csv' )
precipation_df.head()
# Out:
#    year Country_code  annual_precipitation_mm                      country
# 0  2025          AFE                      NaN  Africa Eastern and Southern
# 1  2024          AFE                      NaN  Africa Eastern and Southern
# 2  2023          AFE                      NaN  Africa Eastern and Southern
# 3  2022          AFE                      NaN  Africa Eastern and Southern
# 4  2021          AFE                      NaN  Africa Eastern and Southern
